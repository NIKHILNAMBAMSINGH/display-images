# %%
import os
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt

# %%
#the path of each file
images_path = ['D:/New Brain Tumor dataset/Training/glioma/Tr-gl_0073.jpg',
               'D:/New Brain Tumor dataset/Training/meningioma/Tr-me_0013.jpg',
               'D:/New Brain Tumor dataset/Training/notumor/Tr-no_0033.jpg',
               'D:/New Brain Tumor dataset/Training/pituitary/Tr-pi_0010.jpg']

# %%
#to display each file in the training set
import cv2
from matplotlib import pyplot as plt
  

fig = plt.figure(figsize=(10, 7))
  

rows = 2
columns = 2
  

Image1 = cv2.imread('D:/New Brain Tumor dataset/Training/glioma/Tr-gl_0073.jpg')
Image2 = cv2.imread('D:/New Brain Tumor dataset/Training/meningioma/Tr-me_0013.jpg')
Image3 = cv2.imread('D:/New Brain Tumor dataset/Training/notumor/Tr-no_0033.jpg')
Image4 = cv2.imread('D:/New Brain Tumor dataset/Training/pituitary/Tr-pi_0010.jpg')
  

fig.add_subplot(rows, columns, 1)
  

plt.imshow(Image1)
plt.axis('off')
plt.title("Glioma")
  

fig.add_subplot(rows, columns, 2)
  

plt.imshow(Image2)
plt.axis('off')
plt.title("Meningioma")
  

fig.add_subplot(rows, columns, 3)
  

plt.imshow(Image3)
plt.axis('off')
plt.title("No Tumor")
  

fig.add_subplot(rows, columns, 4)
  

plt.imshow(Image4)
plt.axis('off')
plt.title("Pituitary")
# Out:
# Text(0.5, 1.0, 'Pituitary')
